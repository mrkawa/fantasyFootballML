# %%
import pandas as pd

df = pd.read_excel('modelIterations.xlsx', header=[0,1,2], index=False, index_col=[0,1,2])

df = df.unstack().stack(level=[0,1,2]).reset_index()

df = df.rename(columns={'level_0':'Algorithm', 'level_1':'Type', 'level_2':'Phase', 'level_3':'Sub-phase', 'level_4':'Position'})

df.to_csv('res.csv')

df
# Out:
#       Algorithm                   Type              Phase  \
# 0     Neighbors                    KNN        Multioutput
# 1     Neighbors                    KNN        Multioutput
# 2     Neighbors                    KNN        Multioutput
# 3     Neighbors                    KNN        Multioutput
# 4     Neighbors                    KNN        Multioutput
# ..          ...                    ...                ...
# 178  Regression                  Ridge  Season Total Data
# 179         SVM  Kernel Ridge (Linear)  Season Total Data
# 180         SVM  Kernel Ridge (Linear)  Season Total Data
# 181         SVM  Kernel Ridge (Linear)  Season Total Data
# 182         SVM  Kernel Ridge (Linear)  Season Total Data
#
#                                Sub-phase Position   MAE  RMSE   R^2
# 0    Downselected, Standardized Features       QB  61.4  79.2  0.33
# 1    Downselected, Standardized Features       RB  44.8  67.5  0.30
# 2    Downselected, Standardized Features       TE  23.0  31.9  0.39
# 3    Downselected, Standardized Features       WR  38.4  59.5  0.30
# 4                              Optimized       QB  53.0  72.3  0.44
# ..                                   ...      ...   ...   ...   ...
# 178          Hyperparameter Optimization      All  31.6  47.3  0.45
# 179                           Base Model      All  29.9  50.4  0.38
# 180          Hyperparameter Optimization      All  29.9  50.3  0.38
# 181             Manual Feature Selection      All  29.7  50.2  0.38
# 182                      Standardization      All  51.7  67.7 -0.13
#
# [183 rows x 8 columns]
